# %% [markdown]
# <a href="https://colab.research.google.com/github/dangi0/Programmazione-con-Python/blob/main/Dataset_Pratica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
BASE_URL = "https://raw.githubusercontent.com/ProfAI/machine-learning-fondamenti/main/datasets/"

# %%
df = pd.read_csv(BASE_URL+"shirts_example.csv", index_col=0)

# %%
df.head(5)
# Out:
#   taglia  colore  prezzo
# 0      S  bianco    4.99
# 1      M  bianco   19.99
# 2     XL  bianco   12.49
# 3     XL  bianco   14.99
# 4      S  bianco   14.99

# %%
df_tsv = pd.read_csv(BASE_URL+"shirts_example.tsv", sep="\t", index_col=0)

# %%
df_tsv.head(5)
# Out:
#   taglia  colore  prezzo
# 0      S  bianco    4.99
# 1      M  bianco   19.99
# 2     XL  bianco   12.49
# 3     XL  bianco   14.99
# 4      S  bianco   14.99

# %%
df_json = pd.read_json(BASE_URL+"shirts_example.json")

# %%
df_json.head(10)
# Out:
#   taglia  colore  prezzo
# 0      S  bianco    4.99
# 1      M  bianco   19.99
# 2     XL  bianco   12.49
# 3     XL  bianco   14.99
# 4      S  bianco   14.99
# 5      S   verde    7.99
# 6      M   verde    4.99
# 7      L   verde   12.49
# 8     XL  bianco   12.49
# 9      M   verde   19.99
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['prezzo'].plot(kind='hist', bins=20, title='prezzo')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_11.groupby('taglia').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_11.groupby('taglia').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_10['prezzo'].plot(kind='hist', bins=20, title='prezzo')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_xml = pd.read_xml(BASE_URL+"shirts_example.xml")

# %%
df_xml = df_xml.set_index('id')

# %%
df_xml
# Out:
#    taglia  colore  prezzo
# id
# 0       S  bianco    4.99
# 1       M  bianco   19.99
# 2      XL  bianco   12.49
# 3      XL  bianco   14.99
# 4       S  bianco   14.99
# 5       S   verde    7.99
# 6       M   verde    4.99
# 7       L   verde   12.49
# 8      XL  bianco   12.49
# 9       M   verde   19.99

# %%
df_html = pd.read_html(BASE_URL+"shirts_example.html", index_col=0, header=0)

# %%
df_html[0].head()
# Out:
#   taglia  colore  prezzo
# 0      S  bianco    4.99
# 1      M  bianco   19.99
# 2     XL  bianco   12.49
# 3     XL  bianco   14.99
# 4      S  bianco   14.99

# %%
df_ods = pd.read_excel(BASE_URL+"shirts_example.ods", index_col=0)

# %%
df_ods
# Out:
#   taglia  colore  prezzo
# 0      S  bianco    4.99
# 1      M  bianco   19.99
# 2     XL  bianco   12.49
# 3     XL  bianco   14.99
# 4      S  bianco   14.99
# 5      S   verde    7.99
# 6      M   verde    4.99
# 7      L   verde   12.49
# 8     XL  bianco   12.49
# 9      M   verde   19.99
